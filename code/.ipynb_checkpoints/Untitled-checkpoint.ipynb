# %%
import os
import json
import re
import csv 
import pickle as pkl
import difflib
import numpy as np
from copy import deepcopy
import pandas as pd
from itertools import islice   #导入迭代器

# %%
csvname = 'JOURNAL OF MULTIVARIATE ANALYSIS.csv'                               #转化为小写，并去除空格
path_csv = 'D:/bigdatahw/dissertation/pre_defence/data'
filepath = path_csv+'/'+csvname

# %%
a = pd.read_csv(filepath, sep=',',header=0, encoding='ISO-8859-1')

# %%
#该日期

# %%
a = a.iloc[:,0:13]

# %%
a.dropna(axis=0, how='all', inplace=True)
# Out:
# C:\Users\Bokkin Wang\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a.drop_duplicates(keep='first')
# Out:
#                                                   title  \
# 0            Maximal correlation in a non-diagonal case
# 1     On relations between BLUEs under two transform...
# 2     A new test for the proportionality of two larg...
# 3     A note on the computation of sharp numerical b...
# 4     Computationally efficient banding of large cov...
# 5     Specification test for Markov models with meas...
# 6         Goodness of fit tests for linear mixed models
# 7     Estimations for some functions of covariance m...
# 8     Analyzing right-censored and length-biased dat...
# 9     Panel data partially linear model with fixed e...
# 10    High-dimensional mean estimation via l(1) pena...
# 11    The spatial sign covariance matrix with unknow...
# 12    Dependence properties of multivariate max-stab...
# 13    Semiparametric estimation of a class of genera...
# 14    Infinitely divisible multivariate and matrix G...
# 15    A note on the CLT of the LSS for sample covari...
# ...

# %%
a.iloc[:,3] = a['published'].apply(lambda x : x.split('>')[1].split('<')[0])
# Out:
# C:\Users\Bokkin Wang\Anaconda3\lib\site-packages\pandas\core\indexing.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
a
# Out:
#                                                   title  \
# 0            Maximal correlation in a non-diagonal case
# 1     On relations between BLUEs under two transform...
# 2     A new test for the proportionality of two larg...
# 3     A note on the computation of sharp numerical b...
# 4     Computationally efficient banding of large cov...
# 5     Specification test for Markov models with meas...
# 6         Goodness of fit tests for linear mixed models
# 7     Estimations for some functions of covariance m...
# 8     Analyzing right-censored and length-biased dat...
# 9     Panel data partially linear model with fixed e...
# 10    High-dimensional mean estimation via l(1) pena...
# 11    The spatial sign covariance matrix with unknow...
# 12    Dependence properties of multivariate max-stab...
# 13    Semiparametric estimation of a class of genera...
# 14    Infinitely divisible multivariate and matrix G...
# 15    A note on the CLT of the LSS for sample covari...
# ...

# %%
a.to_csv(filepath,encoding='ISO-8859-1')

# %%
filepath
# Out:
# 'D:/bigdatahw/dissertation/pre_defence/data/JOURNAL OF MULTIVARIATE ANALYSIS.csv'
